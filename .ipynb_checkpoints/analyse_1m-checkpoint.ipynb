# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as stats
import numpy as np

# %%
def get_titles_filtered_by_milestones() :
    titles = {"tape": [], "vinyl": [], "kassette": [], "cd": [], "mp3": []}

    stats = pd.read_pickle(r'1m-highest.pkl')

    for data in stats:
        try:                        
            if data["year"] < 1926:
                continue
            elif data["year"] < 1947:
                titles["tape"].append(data)
            elif data["year"] < 1967:
                titles["vinyl"].append(data)
            elif data["year"] < 1981:
                titles["kassette"].append(data)
            elif data["year"] < 1989:
                titles["cd"].append(data)
            else: 
                titles["mp3"].append(data)
            
        except AttributeError:
            print(data)

    return titles

# %%
titles = get_titles_filtered_by_milestones()

# %%
df_list = [pd.DataFrame(titles['tape']), pd.DataFrame(titles['vinyl']), pd.DataFrame(titles['kassette']), pd.DataFrame(titles['cd']), pd.DataFrame(titles['mp3'])]

combinedDf = pd.concat(df_list)

combinedDf.describe()
# Out:
#                tempo            key           year       duration  \
# count  515558.000000  515558.000000  515558.000000  515558.000000
# mean      124.785492       5.314504    1998.399841     246.870747
# std        34.873004       3.601111      10.921812     115.548127
# min         0.000000       0.000000    1926.000000       0.313020
# 25%        98.992000       2.000000    1994.000000     183.144040
# 50%       122.489000       5.000000    2002.000000     229.955460
# 75%       145.274000       9.000000    2006.000000     287.137510
# max       280.955000      11.000000    2011.000000    3024.665670
#
#             loudness
# count  515558.000000
# mean       -9.699284
# std         4.942066
# min       -57.004000
# 25%       -12.176000
# 50%        -8.614000
# 75%        -6.128000
# max         4.150000

# %%
# Properties of Tape-Data
pd.DataFrame(titles['tape']).describe()
# Out:
#             tempo         key         year    duration    loudness
# count  655.000000  655.000000   655.000000  655.000000  655.000000
# mean   107.140798    5.129771  1934.867176  182.720334  -18.037707
# std     30.211652    3.498355     6.183168   29.118985    4.574017
# min      0.000000    0.000000  1926.000000    2.585670  -37.562000
# 25%     86.489000    2.000000  1929.000000  168.920360  -20.375500
# 50%    100.192000    5.000000  1934.000000  180.819140  -17.244000
# 75%    119.565500    8.000000  1940.000000  192.482810  -15.050500
# max    253.253000   11.000000  1946.000000  394.997100   -5.327000

# %%
# Properties of vinyl-Data
pd.DataFrame(titles['vinyl']).describe()
# Out:
#              tempo          key         year     duration     loudness
# count  9209.000000  9209.000000  9209.000000  9209.000000  9209.000000
# mean    117.110764     5.046911  1961.002823   194.125365   -13.334781
# std      34.431892     3.484759     4.323399   108.751364     4.845740
# min       0.000000     0.000000  1947.000000     2.063220   -40.456000
# 25%      93.394000     2.000000  1958.000000   143.411790   -16.109000
# 50%     113.884000     5.000000  1962.000000   165.041180   -12.787000
# 75%     137.254000     8.000000  1965.000000   196.388120    -9.972000
# max     254.028000    11.000000  1966.000000  1781.446080    -1.402000

# %%
# Properties of kassette-Data
pd.DataFrame(titles['kassette']).describe()
# Out:
#               tempo           key          year      duration      loudness
# count  33645.000000  33645.000000  33645.000000  33645.000000  33645.000000
# mean     125.358302      5.163620   1974.087621    242.031197    -11.806726
# std       33.447742      3.554032      4.024084    123.409632      4.270152
# min        0.000000      0.000000   1967.000000      0.757100    -40.726000
# 25%      100.917000      2.000000   1971.000000    173.165260    -14.060000
# 50%      122.374000      5.000000   1974.000000    214.543220    -11.356000
# 75%      145.307000      9.000000   1978.000000    276.375060     -8.807000
# max      260.547000     11.000000   1980.000000   2723.970160      2.067000

# %%
# Properties of kassette-Data
pd.DataFrame(titles['cd']).describe()
# Out:
#               tempo           key          year      duration      loudness
# count  32054.000000  32054.000000  32054.000000  32054.000000  32054.000000
# mean     127.001919      5.323673   1984.928558    241.192840    -11.463438
# std       32.977298      3.615790      2.336805    102.221422      4.689234
# min        0.000000      0.000000   1981.000000      1.201180    -54.477000
# 25%      104.406000      2.000000   1983.000000    183.196280    -13.851000
# 50%      123.786000      5.000000   1985.000000    229.772610    -10.996000
# 75%      145.830250      9.000000   1987.000000    281.253420     -8.118000
# max      280.955000     11.000000   1988.000000   1959.000360     -1.218000

# %%
# Properties of kassette-Data
pd.DataFrame(titles['mp3']).describe()
# Out:
#                tempo            key           year       duration  \
# count  439995.000000  439995.000000  439995.000000  439995.000000
# mean      124.767120       5.331249    2002.117601     248.853899
# std        35.099351       3.605679       5.492443     115.746823
# min         0.000000       0.000000    1989.000000       0.313020
# 25%        98.574000       2.000000    1998.000000     186.174240
# 50%       122.657000       6.000000    2003.000000     232.437100
# 75%       145.470500       9.000000    2007.000000     289.357910
# max       275.393000      11.000000    2011.000000    3024.665670
#
#             loudness
# count  439995.000000
# mean       -9.321111
# std         4.900040
# min       -57.004000
# 25%       -11.583000
# 50%        -8.139000
# 75%        -5.865000
# max         4.150000

# %%
titles["tape"][0]
# Out:
# {'tempo': 101.501,
#  'artist_name': 'Peetie Wheatstraw',
#  'track_name': 'Shack Bully Stomp',
#  'key': 9,
#  'year': 1938,
#  'duration': 159.84281,
#  'loudness': -19.519}

# %%
# get size of arrays

print("tape: " + str(len(titles["tape"])))
print("vinyl: " + str(len(titles["vinyl"])))
print("kassette: " + str(len(titles["kassette"])))
print("cd: " + str(len(titles["cd"])))
print("mp3: " + str(len(titles["mp3"])))
# Out:
# tape: 655
# vinyl: 9209
# kassette: 33645
# cd: 32054
# mp3: 439995

# %%
def showViolinPlot(data):
    # Create a figure instance
    fig = plt.figure()

    # Create an axes instance
    ax = fig.add_axes([0,0,1,1])

    # Create the boxplot
    bpm = ax.violinplot(data, showmeans=True, showmedians=True)
    plt.show()

# %%
def showHistogram(data):
    # Create a figure instance
    fig = plt.figure()

    # Create an axes instance
    ax = fig.add_axes([0,0,1,1])

    # Create the boxplot
    ax.hist(data, bins=int(max(data)-min(data)))
    plt.show()

# %%
def create_line_histogram(data, binFactor):

    density = stats.gaussian_kde(data)
    n, x, _ = plt.hist(data, bins=np.linspace(int(min(data)), int(max(data)), int((max(data)-min(data)) / binFactor)), histtype=u'stepfilled', density=True)
    plt.axvline(data.mean(), color='red', linestyle='dashed', linewidth=1, label='mean')  
    plt.axvline(data.median(), color='black', linestyle='dashed', linewidth=1, label='median')  
    return plt.plot(x, density(x), color='black', linewidth=2)

# %%
df_tape = pd.DataFrame(titles["tape"])
df_tape.describe()

df_vinyl = pd.DataFrame(titles["vinyl"])
df_kassette = pd.DataFrame(titles["kassette"])
df_cd = pd.DataFrame(titles["cd"])
df_mp3 = pd.DataFrame(titles["mp3"])
dataframes = [df_tape, df_vinyl, df_kassette, df_cd, df_mp3]

# %%
def remove_outliers(data):
    return data[data.between(data.quantile(.15), data.quantile(.85))]

# %%
showViolinPlot(df_tape['tempo'])

# %%
create_line_histogram(df_tape['tempo'], 2)
plt.show()

# %%
def create_stacked_histograms(property, binFactor):

    fig = plt.figure()

    fig.suptitle(str(property) + ' histograms')
    fig.supxlabel(property)
    fig.supylabel('Density')
    fig.set_size_inches(10, 10)

    ax1 = plt.subplot(511)
    plt.title('Tape')
    create_line_histogram(df_tape[property], binFactor)
    plt.legend(loc='upper right')

    plt.subplot(512, sharex=ax1)
    plt.title('Vinyl')
    create_line_histogram(df_vinyl[property], binFactor)

    plt.subplot(513, sharex=ax1)
    plt.title('Kassette')
    create_line_histogram(df_kassette[property], binFactor)

    plt.subplot(514, sharex=ax1)
    plt.title('CD')
    create_line_histogram(df_cd[property], binFactor)

    plt.subplot(515, sharex=ax1)
    plt.title('MP3')
    create_line_histogram(df_mp3[property], binFactor)

    fig.subplots_adjust(hspace=0.7)

    plt.show()

# %%
def create_stacked_histograms_no_outliers(property, binFactor):

    fig = plt.figure()

    fig.suptitle(str(property) + ' histograms without outliers')
    fig.supxlabel(property)
    fig.supylabel('Density')
    fig.set_size_inches(10, 10)

    ax1 = plt.subplot(511)
    plt.title('Tape')
    create_line_histogram(remove_outliers(df_tape[property]), binFactor)
    plt.legend(loc='upper right')

    plt.subplot(512, sharex=ax1)
    plt.title('Vinyl')
    create_line_histogram(remove_outliers(df_vinyl[property]), binFactor)

    plt.subplot(513, sharex=ax1)
    plt.title('Kassette')
    create_line_histogram(remove_outliers(df_kassette[property]), binFactor)

    plt.subplot(514, sharex=ax1)
    plt.title('CD')
    create_line_histogram(remove_outliers(df_cd[property]), binFactor)

    plt.subplot(515, sharex=ax1)
    plt.title('MP3')
    create_line_histogram(remove_outliers(df_mp3[property]), binFactor)

    fig.subplots_adjust(hspace=0.7)

    plt.show()

# %%
len(df_kassette[np.abs(df_kassette-df_kassette.mean()) <= (3*df_kassette.std())]['duration'])
len(df_kassette['duration'])
# Out:
# C:\Users\robin\AppData\Local\Temp/ipykernel_13592/2119964338.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   len(df_kassette[np.abs(df_kassette-df_kassette.mean()) <= (3*df_kassette.std())]['duration'])
# C:\Users\robin\AppData\Local\Temp/ipykernel_13592/2119964338.py:1: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version. Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   len(df_kassette[np.abs(df_kassette-df_kassette.mean()) <= (3*df_kassette.std())]['duration'])
# 33645

# %%
create_stacked_histograms('tempo', 3)

# %%
create_stacked_histograms('duration', 2)

# %%
create_stacked_histograms('loudness', 0.1)

# %%
create_stacked_histograms_no_outliers('tempo', 1)

# %%
create_stacked_histograms_no_outliers('loudness', 0.1)

# %%
create_stacked_histograms_no_outliers('duration', 1)
